# %% [markdown]
# # Tesis

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.6/780.6 kB 11.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %% [markdown]
# # Train on custom dataset

# %%
# !unzip -q Tesis_sin.zip

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(data='data.yaml', epochs=5, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 174MB/s]
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Run inference on the source

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('runs/detect/train2/weights/best.pt')

# Run inference on 'bus.jpg' with arguments
model.predict(['lays1.jpeg', 'lays2.jpeg','lays3.jpeg'], save=True, imgsz=640, conf=0.30)
# Out:
# 0: 640x640 1 Classic, 1 Lays, 46.1ms
# 1: 640x640 1 Lays, 46.1ms
# 2: 640x640 1 Lays, 46.1ms
# Speed: 2.3ms preprocess, 46.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bar.B.Q', 1: 'Barbecue', 2: 'Cheddar - Sour Cream', 3: 'Cheddar Jalapeno', 4: 'Classic', 5: 'Dill Pickle', 6: 'Flamin Hot', 7: 'French Cheese', 8: 'Honey Barbecue', 9: 'Lays', 10: 'Masala', 11: 'PAPRIKA', 12: 'Poppables', 13: 'Salt - Vinegar', 14: 'Salted', 15: 'Sour Cream - Onion', 16: 'Sweet Southern Heat Barbecue', 17: 'Wavy', 18: 'Yogurt - Herb'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
# ...

# %%
# Load a pretrained YOLOv8n model
model = YOLO('runs/detect/train/weights/best.pt')

# Run inference on 'bus.jpg' with arguments
model.predict('prueba_lays.mp4', save=True, imgsz=640, conf=0.5)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/270) /content/prueba_lays.mp4: 384x640 1 Lays, 109.9ms
# video 1/1 (frame 2/270) /content/prueba_lays.mp4: 384x640 1 Lays, 31.6ms
# video 1/1 (frame 3/270) /content/prueba_lays.mp4: 384x640 1 Lays, 31.6ms
# video 1/1 (frame 4/270) /content/prueba_lays.mp4: 384x640 1 Lays, 31.6ms
# video 1/1 (frame 5/270) /content/prueba_lays.mp4: 384x640 1 Lays, 31.6ms
# ...
